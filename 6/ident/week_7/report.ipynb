# %% [markdown]
# # <center> Capstone проект №1. Идентификация пользователей по посещенным веб-страницам

# %% [markdown]
# В этом проекте мы будем решать задачу идентификации пользователя по его поведению в сети Интернет.
#
# Мы будем решать
# задачу: по последовательности из нескольких веб-сайтов, посещенных подряд один и тем же человеком, мы будем идентифицировать этого человека. Идея такая: пользователи Интернета по-разному переходят по ссылкам, и это может помогать их идентифицировать (кто-то сначала в почту, потом про футбол почитать, затем новости, контакт, потом наконец – работать, кто-то – сразу работать).

# %% [markdown]
# Поздравляю! Вы подошли к финальной стадии проекта, сейчас осталось собрать вместе все, над чем Вы работали все это время.
#
# Отчет должен быть выполнен в формате pdf или тетрадки Jupyter, но вообще и тут мало что ограничивает фантазию, Вы можете придумать свой вариант.
#
# Структура отчета в целом соответствует структуре проекта.
#
# Основные шаги:
# * цели и задачи проекта, описание исходных и обработанных данных и признаков.
# * первичный анализ признаков
# * первичный визуальный анализ признаков
# * если пришли к каким-то "инсайтам", обнаружили закономерности – изложите
# * описание предобработки данных
# * если создаются признаки, то описание этого процесса
# * кросс-валидация, построение кривых валидации и обучения
# * оценка модели с описанием выбранной метрики. Опишите простыми словами качество модели, как она может применяться
# * выводы: как построенная модель может применяться на практике, какие бизнес-задачи решать. Подведите итог, опишите, что еще можно сделать, а что сделать не удалось.
#
# За творческий подход, реализацию дополнительных алгоритмов, построение уникальных признаков и т.д. будут начисляться дополнительные баллы.
#
# Описание делайте на формальном языке, так чтоб его не стыдно потом было бы показать будущему руководителю. Структурируйте свои мысли и понятно их излагайте. Можете даже добавить, чему Вы научились в ходе проекта. И главное: проявляйте фантазию!
# Review criteria
#
# Задание будет оцениваться на основании приложенного отчета. Отчет может быть выполнен в свободной форме: от формального документа в официальном стиле, до яркой презентации или небольшого интерактивного демо (например, jupyter notebook).

# %%
r="{}".format(" ".join(['as','ss']))

# %%
r
# Out:
# 'as ss'
